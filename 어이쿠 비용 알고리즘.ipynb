# %%
First =int(input("2박3일 가는 사람수를 입력하세요."))
Second = int(input("1박2일 가는 사람수를 입력하세요."))

#사람 늘어날때마다 갯수도 수정되게 설정하기
#용달차 가격
#100,000
A=100000//(First+Second)
print("용달차 가격은",100000//(First+Second),"원 입니다.")

#소주 가격
#소주 1인당 첫날은 1병 둘째날은 2병
#소주 1병 가격 = 1080원
#소주 한짝 가격= 21600원
a=(First+Second)*1 #첫날 소주 개수
b=First*2      	#둘째날 소주 개수
soju=a+b   #총 소주 개수
sojuneedFirst=round(a/20+0.5) #첫날 필요한 소주 박스 개수
sojuneedSecond=round(b/20+0.5) #둘째날 필요한 소주 박스 개수
sojuneedall=round((a+b)/20+0.5) #다합쳐서 필요한 소주 박스 개수
sojuone=sojuneedall/3 #첫날 소주비율
sojutwo=sojuone*2  #둘째날 소주 비율
print(sojuneedall)

print("소주는 총 ",a+b,"개 필요합니다.")
print("그러므로 소주는 총",sojuneedall,"짝 만큼 필요합니다.")
B= sojuone*21600//(First+Second)
print("첫날 소주 가격은", sojuone*21600//(First+Second),"원 입니다.")
C=sojutwo*21600//(First)
print("둘째날 소주 가격은",sojutwo*21600//(First),"원 입니다.")
print("그러므로 소주 가격은 총",sojuneedall*21600,"원 입니다.")
#맥주 가격
#맥주 1인당 하루 0.25페트 =4인 하루 1페트
#맥주 1페트 가격 = 4200원
#맥주 한짝 가격 = 25200

c=(First+Second)*0.25 #첫날 맥주 개수
d=First*0.25        	#둘째날 맥주 개수
beer=c+d	#총 맥주 필요 개수
beerFirst=round(c/6+0.5) #첫날 필요한 맥주 박스 개수
beerSecond=round(d/6+0.5) #둘째날 필요한 맥주 박스 개수
beerall=round(beer/6+0.5) # 총 필요한 맥주 박스 개수
beerone=beerall/2
beertwo=beerall/2
print("맥주는 총",c+d,"개 필요합니다.")
print("그러므로 맥주는 총",beerall,"짝 만큼 필요합니다.")
D=beerone*25200//(First+Second)
print("첫날 맥주 가격은",beerone*25200//(First+Second),"원 입니다.")
E=beertwo*25200//(First)
print("둘째날 맥주 가격은",beertwo*25200//(First),"원 입니다.")
print("그러므로 맥주 가격은 총",beerall*25200,"원 입니다.")

#음료수 가격
#인당 하루 1페트씩
#1페트 평균 가격 = 2000원
e=(First+Second)*1 #첫날 음료수 개수
f=(First)*1       	#둘째날 음료수 개수
print("음료수는 총",e+f,"개 필요합니다.")
F=e*2000//(First+Second)
print("첫날 음료수 가격은", e*2000//(First+Second),"원 입니다.")
G=f*2000//(First)
print("둘째날 음료수 가격은",f*2000//(First),"원 입니다.")
print("그러므로 음료수 가격은 총",(e+f)*2000,"원 입니다.")
#물 가격
#인당 하루 1페트씩
#1페트  가격 = 420원
#물 한짝 가격 = 2520
g=(First+Second)*1  #첫날 물 개수
h=(First)*1    	#둘째날 음료수 개수
water=g+h  #물 필요한 개수
waterFirst=round(g/6+0.5) #첫째날 필요한 물 박스 개수
waterSecond=round(h/6+0.5) #둘째날 필요한 물 박스 개수
waterall=round(water/6+0.5) #총필요한 물 박스 개수
waterone=waterall/2
watertwo=waterall/2
print("물은 총",water,"개 만큼 필요합니다.")
print("그러므로 물은",waterall,"짝 만큼 필요합니다.")
H=waterone*2520//(First+Second)
print("첫날 물 가격은", waterone*2520//(First+Second),"원 입니다.")
I=watertwo*2520//(First)
print("둘째날 물 가격은",watertwo*2520//(First),"원 입니다.")
print("그러므로 물 가격은 총",waterall*2520,"원 입니다.")
#일회용품 가격
#일회용품은 균등분배
#32,430원
J=32430//(First+Second)
print("일회용품 가격은", 32430//(First+Second),"원 입니다.")

#고기 가격
#고기는 1인당 400g
#고기 1g 가격 =9.2원
#고기 100g 가격 = 920원
#고기 400g 가격 = 3680원
i=(First+Second)*400 #고기 필요 그람수
print("고기는 총",i,"g 필요합니다.")
K=i*9.2//(First+Second)
print("고기 가격은 ", i*9.2//(First+Second),"원 입니다.")
print("그러므로 고기 가격은 총",i*9.2,"원 입니다.")
#숙소 가격
#숙소가격은 균등분배
#800,000원
j=(First+Second)
k=First
L=400000//(First+Second)
print("첫날 숙소 가격은", 400000//(First+Second),"원 입니다.")
P=400000//(First)
print("둘째날 숙소 가격은",400000//(First),"원 입니다.")
#각조 지원금
#각조지원금은 균등분배
#120,000원
M=120000//(First+Second)
print("지원금 가격은",120000//(First+Second),"원 입니다.")
print("1박2일 가격은", A+B+D+F+H+J+K+L+M,"원 입니다.")
print("2박3일 가격은", A+B+C+D+E+F+G+H+I+J+K+L+M+P,"원 입니다.")

l=A+B+D+F+H+J+K+L+M #소문자 엘(변수)
m=A+B+C+D+E+F+G+H+I+J+K+L+M+P

n=(55000*First)+(35000*Second)
o=(First*m)+(Second*l)
print("우리가 걷은 총 비용은",(55000*First)+(30000*Second),"원 입니다.")
print("사용될 총 비용은",(First*m)+(Second*l)+3980,"원 입니다.")#3980원은 500ml 생수가격
print("우리가 사용 하고 남은 비용은",n-o,"원 입니다.")
# Out:
# 2박3일 가는 사람수를 입력하세요.32
# 1박2일 가는 사람수를 입력하세요.2
# 용달차 가격은 2941 원 입니다.
# 5
# 소주는 총  98 개 필요합니다.
# 그러므로 소주는 총 5 짝 만큼 필요합니다.
# 첫날 소주 가격은 1058.0 원 입니다.
# 둘째날 소주 가격은 2250.0 원 입니다.
# 그러므로 소주 가격은 총 108000 원 입니다.
# 맥주는 총 16.5 개 필요합니다.
# 그러므로 맥주는 총 3 짝 만큼 필요합니다.
# 첫날 맥주 가격은 1111.0 원 입니다.
# 둘째날 맥주 가격은 1181.0 원 입니다.
# 그러므로 맥주 가격은 총 75600 원 입니다.
# 음료수는 총 66 개 필요합니다.
# 첫날 음료수 가격은 2000 원 입니다.
# 둘째날 음료수 가격은 2000 원 입니다.
# 그러므로 음료수 가격은 총 132000 원 입니다.
# 물은 총 66 개 만큼 필요합니다.
# 그러므로 물은 12 짝 만큼 필요합니다.
# 첫날 물 가격은 444.0 원 입니다.
# 둘째날 물 가격은 472.0 원 입니다.
# 그러므로 물 가격은 총 30240 원 입니다.
# 일회용품 가격은 953 원 입니다.
# 고기는 총 13600 g 필요합니다.
# 고기 가격은  3679.0 원 입니다.
# 그러므로 고기 가격은 총 125119.99999999999 원 입니다.
# 첫날 숙소 가격은 11764 원 입니다.
# 둘째날 숙소 가격은 12500 원 입니다.
# 지원금 가격은 3529 원 입니다.
# 1박2일 가격은 27479.0 원 입니다.
# 2박3일 가격은 45882.0 원 입니다.
# 우리가 걷은 총 비용은 1820000 원 입니다.
# 사용될 총 비용은 1527162.0 원 입니다.
# 우리가 사용 하고 남은 비용은 306818.0 원 입니다.
